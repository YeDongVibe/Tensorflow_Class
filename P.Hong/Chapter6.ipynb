# %% [markdown]
# <시작하세요! 텐서플로 2.0 프로그래밍> 예제코드입니다.
#
# - 예제 코드를 실행하기 위해서는 [파일] > [드라이브에 사본 저장]으로 본인의 계정에 사본을 만든 다음 실행하면 됩니다.
# - 예제 코드는 [깃허브 저장소](https://github.com/wikibook/tf2)에서도 동일하게 제공됩니다. 예제에 대한 질문이나 책에 대한 질문은 깃허브 저장소의 [Issues](https://github.com/wikibook/tf2/issues)에 올려주세요.
# - 각 장의 예제 파일은 처음부터 끝까지 실행하는 상황을 가정하고 작성되었습니다. 혹시 세션이 다운되는 등의 이유로 실행이 되지 않는 경우가 있다면, 필요한 라이브러리를 import 하신 후에 실행하시면 됩니다. (tensorflow, numpy, pandas 등)

# %%
#

# %%
# 텐서플로 2 버전 선택
try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass
import tensorflow as tf
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# # 6.2 주요 레이어 정리

# %%
# 그림 6.8 출력 코드. 참고 링크 : https://stackoverflow.com/a/37435090/2689257
import matplotlib.pyplot as plt

image_path = tf.keras.utils.get_file('cat.jpg', 'http://bit.ly/33U6mH9')
image = plt.imread(image_path)

titles = ['RGB Image', 'Red channel', 'Green channel', 'Blue channel']
cmaps = [None, plt.cm.Reds_r, plt.cm.Greens_r, plt.cm.Blues_r]

from numpy import array, zeros_like
def channel(image, color): #해당 칼러를 추출
    if color not in (0, 1, 2): return image
    c = image[..., color]
    z = zeros_like(c)
    return array([(c, z, z), (z, c, z), (z, z, c)][color]).transpose(1,2,0)
  
colors = range(-1, 3)
fig, axes = plt.subplots(1, 4, figsize=(13,3))
objs = zip(axes, titles, colors)
for ax, title, color in objs:
    ax.imshow(channel(image, color))
    ax.set_title(title)
    ax.set_xticks(())
    ax.set_yticks(())

plt.show()
# Out:
# Downloading data from http://bit.ly/33U6mH9
# 15922/15922 [==============================] - 0s 0us/step

# %%
# 6.1 Conv2D 레이어 생성 코드 - 필터는 가중치값의 행렬
conv1 = tf.keras.layers.Conv2D(kernel_size=(3,3),strides=(2,2),padding='valid' ,filters=16)
# 필터가 합성곱층의 가중치 파라미터 W에 해당 > 학습단계에서 적절한 필터를 찾도록 학습

# %%
# 6.2 MaxPool2D 레이어 생성 코드 - 가중치가 없음  > 학습되지 않음
pool1 = tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2))

# %%
# 6.3 Dropout 레이어 생성 코드 - 가중치 없다 > 학습 없다
pool1 = tf.keras.layers.Dropout(rate=0.3)

# %% [markdown]
# # 6.3 Fashion MNIST with CNN

# %%
# http://taewan.kim/post/cnn/ > 컨볼루션 학습에 도움이 된다 
# https://wikidocs.net/62306
# https://89douner.tistory.com/57

# 6.4 Fashion MNIST 데이터셋 불러오기 및 정규화
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_X, train_Y), (test_X, test_Y) = fashion_mnist.load_data()

train_X = train_X / 255.0 # 정규화
test_X = test_X / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# 6.5 데이터를 채널을 가진 이미지 형태(3차원)으로 바꾸기
# reshape 이전
print(train_X.shape, test_X.shape)

train_X = train_X.reshape(-1, 28, 28, 1) # 흑백 채널 추가 - (60000, 28, 28, 1) 
test_X = test_X.reshape(-1, 28, 28, 1)
#print(train_X)
# reshape 이후
print(train_X.shape, test_X.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
# 6.6 데이터 확인
import matplotlib.pyplot as plt
# 전체 그래프의 사이즈를 width=10, height=10 으로 지정합니다.
plt.figure(figsize=(10, 10))
for c in range(16):
    # 4행 4열로 지정한 grid 에서 c+1 번째의 칸에 그래프를 그립니다. 1~16 번째 칸을 채우게 됩니다.
    plt.subplot(4,4,c+1) # grid(4,4)에서 위 > 아래, 왼쪽 > 오른쪽 순서로 
    plt.imshow(train_X[c].reshape(28,28), cmap='gray') # reshape(28,28)로 3차원 데이터를 다시 2차원 데이터로 변환후 출력
    
plt.show()

# train 데이터의 첫번째 ~ 16번째 까지의 라벨을 프린트합니다.
print(train_Y[:16])
# Out:
# [9 0 0 3 0 2 7 2 5 5 0 9 5 5 7 9]

# %%
# 6.7 Fashion MNIST 분류 컨볼루션 신경망 모델 정의
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=16),# input_shape(28,28,1)은 이미지 높이, 너비, 채널 수
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=32),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64),
    tf.keras.layers.Flatten(),# 다차원 데이터를 1차원으로 정렬 
    tf.keras.layers.Dense(units=128, activation='relu'), # 분류기
    tf.keras.layers.Dense(units=10, activation='softmax') # 분류기 
])
# 경사하강법, 손실함수 
model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 16)        160
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 64)        18496
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,989,642
# Trainable params: 3,989,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 6.8 Google Colab GPU 사양 확인
# !nvidia-smi
# Out:
# Sun Sep  4 14:47:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    27W /  70W |    350MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# 6.9 Fashion MNIST 분류 컨볼루션 신경망 모델 학습
history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

# 손실 그래프 - val_loss는 증가하는 과적합 형태 보임
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
# 검증 정확도 val_accuracy는 학습이 진행될수록 감소 
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()
# 첫째 결과가 테스트 데이터의 loss, 두번째 결과가 테스트 데이터의 accuracy
model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 20s 6ms/step - loss: 0.4752 - accuracy: 0.8307 - val_loss: 0.4007 - val_accuracy: 0.8516
# Epoch 2/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.3423 - accuracy: 0.8751 - val_loss: 0.3767 - val_accuracy: 0.8635
# Epoch 3/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2925 - accuracy: 0.8926 - val_loss: 0.3634 - val_accuracy: 0.8736
# Epoch 4/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.2519 - accuracy: 0.9076 - val_loss: 0.3772 - val_accuracy: 0.8707
# Epoch 5/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.2179 - accuracy: 0.9200 - val_loss: 0.4318 - val_accuracy: 0.8679
# Epoch 6/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1939 - accuracy: 0.9282 - val_loss: 0.4333 - val_accuracy: 0.8667
# Epoch 7/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1725 - accuracy: 0.9368 - val_loss: 0.4747 - val_accuracy: 0.8718
# Epoch 8/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1560 - accuracy: 0.9423 - val_loss: 0.5683 - val_accuracy: 0.8635
# Epoch 9/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1419 - accuracy: 0.9479 - val_loss: 0.5199 - val_accuracy: 0.8677
# Epoch 10/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1272 - accuracy: 0.9528 - val_loss: 0.6004 - val_accuracy: 0.8641
# Epoch 11/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1212 - accuracy: 0.9552 - val_loss: 0.6619 - val_accuracy: 0.8681
# Epoch 12/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1149 - accuracy: 0.9585 - val_loss: 0.6907 - val_accuracy: 0.8675
# Epoch 13/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1036 - accuracy: 0.9630 - val_loss: 0.7327 - val_accuracy: 0.8653
# Epoch 14/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0977 - accuracy: 0.9652 - val_loss: 0.8902 - val_accuracy: 0.8569
# Epoch 15/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0932 - accuracy: 0.9673 - val_loss: 0.8724 - val_accuracy: 0.8704
# Epoch 16/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0904 - accuracy: 0.9678 - val_loss: 0.8355 - val_accuracy: 0.8617
# Epoch 17/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0819 - accuracy: 0.9710 - val_loss: 0.9448 - val_accuracy: 0.8609
# Epoch 18/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0818 - accuracy: 0.9715 - val_loss: 0.9008 - val_accuracy: 0.8628
# Epoch 19/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0813 - accuracy: 0.9711 - val_loss: 0.9624 - val_accuracy: 0.8637
# Epoch 20/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0710 - accuracy: 0.9758 - val_loss: 1.0347 - val_accuracy: 0.8619
# Epoch 21/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0763 - accuracy: 0.9734 - val_loss: 1.1158 - val_accuracy: 0.8599
# Epoch 22/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0695 - accuracy: 0.9763 - val_loss: 1.2319 - val_accuracy: 0.8649
# Epoch 23/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0633 - accuracy: 0.9782 - val_loss: 1.0917 - val_accuracy: 0.8568
# Epoch 24/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.0676 - accuracy: 0.9781 - val_loss: 1.2380 - val_accuracy: 0.8577
# Epoch 25/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0684 - accuracy: 0.9770 - val_loss: 1.2515 - val_accuracy: 0.8612
# [1.321886420249939, 0.8537999987602234]

# %%
# 6.10 Fashion MNIST 분류 컨볼루션 신경망 모델 정의 - 풀링 레이어, 드랍아웃 레이어 추가
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32),
    tf.keras.layers.MaxPool2D(strides=(2,2)), # stride를 증가시킴
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128),
    tf.keras.layers.Flatten(),# flatten 레이어 파라미터수가 30976 > 1152로 감소
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dropout(rate=0.3),# 과적합 개선에 기여
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()# 총 파라미터 숫자가 24만개로 감소
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_2 (Dense)             (None, 128)               147584
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 6.11 Fashion MNIST 분류 컨볼루션 신경망 모델 학습 - 풀링 레이어, 드랍아웃 레이어 추가
history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))
# val_loss는 여전히 증가
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy') # 일정 수준에 머물다
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)# 정확도 89%
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 10s 6ms/step - loss: 0.5233 - accuracy: 0.8093 - val_loss: 0.3728 - val_accuracy: 0.8625
# Epoch 2/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.3625 - accuracy: 0.8686 - val_loss: 0.3271 - val_accuracy: 0.8808
# Epoch 3/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.3150 - accuracy: 0.8864 - val_loss: 0.3122 - val_accuracy: 0.8861
# Epoch 4/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2890 - accuracy: 0.8940 - val_loss: 0.3077 - val_accuracy: 0.8848
# Epoch 5/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2695 - accuracy: 0.9020 - val_loss: 0.3017 - val_accuracy: 0.8875
# Epoch 6/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.2509 - accuracy: 0.9086 - val_loss: 0.2948 - val_accuracy: 0.8959
# Epoch 7/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2399 - accuracy: 0.9110 - val_loss: 0.3113 - val_accuracy: 0.8933
# Epoch 8/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2202 - accuracy: 0.9178 - val_loss: 0.3204 - val_accuracy: 0.8912
# Epoch 9/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2111 - accuracy: 0.9229 - val_loss: 0.3003 - val_accuracy: 0.8973
# Epoch 10/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1967 - accuracy: 0.9260 - val_loss: 0.3146 - val_accuracy: 0.8951
# Epoch 11/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1926 - accuracy: 0.9276 - val_loss: 0.3210 - val_accuracy: 0.8917
# Epoch 12/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1872 - accuracy: 0.9299 - val_loss: 0.3382 - val_accuracy: 0.8975
# Epoch 13/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1742 - accuracy: 0.9338 - val_loss: 0.3242 - val_accuracy: 0.8951
# Epoch 14/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1746 - accuracy: 0.9348 - val_loss: 0.3467 - val_accuracy: 0.8987
# Epoch 15/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1618 - accuracy: 0.9392 - val_loss: 0.3377 - val_accuracy: 0.8991
# Epoch 16/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1565 - accuracy: 0.9404 - val_loss: 0.3747 - val_accuracy: 0.8955
# Epoch 17/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1575 - accuracy: 0.9417 - val_loss: 0.3770 - val_accuracy: 0.8963
# Epoch 18/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1532 - accuracy: 0.9428 - val_loss: 0.4270 - val_accuracy: 0.8913
# Epoch 19/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1504 - accuracy: 0.9452 - val_loss: 0.4215 - val_accuracy: 0.8911
# Epoch 20/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1448 - accuracy: 0.9467 - val_loss: 0.3811 - val_accuracy: 0.8983
# Epoch 21/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1417 - accuracy: 0.9485 - val_loss: 0.4137 - val_accuracy: 0.8954
# Epoch 22/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1355 - accuracy: 0.9501 - val_loss: 0.4703 - val_accuracy: 0.8929
# Epoch 23/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1380 - accuracy: 0.9500 - val_loss: 0.4284 - val_accuracy: 0.8971
# Epoch 24/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1336 - accuracy: 0.9494 - val_loss: 0.4674 - val_accuracy: 0.8985
# Epoch 25/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1258 - accuracy: 0.9530 - val_loss: 0.4203 - val_accuracy: 0.8959
# [0.4554136097431183, 0.887499988079071]

# %% [markdown]
# #6.4 퍼포먼스 높이기

# %%
# 6.12 VGGNet 스타일의 Fashion MNIST 분류 컨볼루션 신경망 모델 정의
# VGG-19 모델이 가장 깊은 레이어 구조 > 특징 추출기 초반에 컨볼루션 레이어 2개 + 풀링 1개를 반복 2차례
# VGG-7: 7은 컨볼루션 갯수와 Dense 갯수 의 합 
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary() # 총 파라미터는 520만개
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 28, 28, 32)        320
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 128)       73856
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_6 (Dense)             (None, 512)               4719104
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 5,240,842
# Trainable params: 5,240,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 6.13 VGGNet 스타일의 Fashion MNIST 분류 컨볼루션 신경망 모델 학습
history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))
# val_loss가 증가하지 않는다
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
#정확도가 92.52%로 좋다
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1286 - accuracy: 0.9524 - val_loss: 0.4688 - val_accuracy: 0.8973
# Epoch 2/25
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.1317 - accuracy: 0.9533 - val_loss: 0.4582 - val_accuracy: 0.8969
# Epoch 3/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1213 - accuracy: 0.9560 - val_loss: 0.4426 - val_accuracy: 0.8942
# Epoch 4/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1245 - accuracy: 0.9539 - val_loss: 0.4905 - val_accuracy: 0.8975
# Epoch 5/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1206 - accuracy: 0.9553 - val_loss: 0.4968 - val_accuracy: 0.9005
# Epoch 6/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1212 - accuracy: 0.9564 - val_loss: 0.4915 - val_accuracy: 0.8954
# Epoch 7/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1099 - accuracy: 0.9590 - val_loss: 0.5627 - val_accuracy: 0.8957
# Epoch 8/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1211 - accuracy: 0.9559 - val_loss: 0.5331 - val_accuracy: 0.8925
# Epoch 9/25
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1139 - accuracy: 0.9590 - val_loss: 0.5591 - val_accuracy: 0.8970
# Epoch 10/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1178 - accuracy: 0.9574 - val_loss: 0.5761 - val_accuracy: 0.8986
# Epoch 11/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1164 - accuracy: 0.9590 - val_loss: 0.5765 - val_accuracy: 0.8967
# Epoch 12/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1106 - accuracy: 0.9593 - val_loss: 0.5116 - val_accuracy: 0.8915
# Epoch 13/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1125 - accuracy: 0.9596 - val_loss: 0.6088 - val_accuracy: 0.8953
# Epoch 14/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1127 - accuracy: 0.9591 - val_loss: 0.5676 - val_accuracy: 0.8920
# Epoch 15/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1065 - accuracy: 0.9618 - val_loss: 0.6077 - val_accuracy: 0.8991
# Epoch 16/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1054 - accuracy: 0.9625 - val_loss: 0.6689 - val_accuracy: 0.8955
# Epoch 17/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1120 - accuracy: 0.9610 - val_loss: 0.5803 - val_accuracy: 0.8979
# Epoch 18/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1075 - accuracy: 0.9623 - val_loss: 0.5687 - val_accuracy: 0.8937
# Epoch 19/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1023 - accuracy: 0.9642 - val_loss: 0.6469 - val_accuracy: 0.8951
# Epoch 20/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1125 - accuracy: 0.9616 - val_loss: 0.6047 - val_accuracy: 0.8937
# Epoch 21/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1050 - accuracy: 0.9634 - val_loss: 0.5984 - val_accuracy: 0.8949
# Epoch 22/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1094 - accuracy: 0.9619 - val_loss: 0.5989 - val_accuracy: 0.8891
# Epoch 23/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0988 - accuracy: 0.9660 - val_loss: 0.6540 - val_accuracy: 0.8962
# Epoch 24/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0974 - accuracy: 0.9662 - val_loss: 0.5357 - val_accuracy: 0.8952
# Epoch 25/25
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0955 - accuracy: 0.9662 - val_loss: 0.5973 - val_accuracy: 0.8936
# [0.6390914916992188, 0.8894000053405762]

# %%
# 6.14 Image Augmentation 데이터 표시
# 이미지 보강은 훈련 데이터에 없는 이미지를 새롭게 만들어 훈련데이터를 보강하는 방법 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# 이 ImageDataGenerator 코드 부분은 다음 링크에서 참조했습니다. 
# https://github.com/franneck94/MNIST-Data-Augmentation/blob/master/mnist.py
# rotation, zoom, shift, flip 등을 지정합니다.
image_generator = ImageDataGenerator( # 훈련데이터의 표현력을 더 좋게 만드는 방법
            rotation_range=10,# 회전
            zoom_range=0.10,
            shear_range=0.5,#기울이거나
            width_shift_range=0.10,# 평행이동
            height_shift_range=0.10,
            horizontal_flip=True,#이미지를 가로로 뒤집다
            vertical_flip=False) # 이미지를 세로로 뒤집다

augment_size = 100
# flow()는 실제로 보강된 이미지를 생성
x_augmented = image_generator.flow(np.tile(train_X[0].reshape(28*28),100).reshape(-1,28,28,1),
                  np.zeros(augment_size), batch_size=augment_size, shuffle=False).next()[0]

# 새롭게 생성된 이미지 표시
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for c in range(100):
    plt.subplot(10,10,c+1)
    plt.axis('off')
    plt.imshow(x_augmented[c].reshape(28,28), cmap='gray')
plt.show()

# %%
# 6.15 Image Augmentation
image_generator = ImageDataGenerator(
            rotation_range=10,
            zoom_range=0.10,
            shear_range=0.5,
            width_shift_range=0.10,
            height_shift_range=0.10,
            horizontal_flip=True,
            vertical_flip=False)

augment_size = 30000 #훈련 데이터의 50%인 30,000개의 이미지 추가를 위해 설정

randidx = np.random.randint(train_X.shape[0], size=augment_size) # 60,000 정수 중에서 30,000 정수를 랜덤하게 추출
# np.random.choice()로 대체 가능
# randidx는 임의 정수들의 넘파이 배열
x_augmented = train_X[randidx].copy() # 복사한다 
y_augmented = train_Y[randidx].copy()
x_augmented = image_generator.flow(x_augmented, np.zeros(augment_size), 
                      batch_size=augment_size, shuffle=False).next()[0]
print(train_X.shape)
# 원래 데이터인 x_train 에 Image Augmentation 된 x_augmented 를 추가합니다.
train_X = np.concatenate((train_X, x_augmented)) # 이미지 보강
train_Y = np.concatenate((train_Y, y_augmented))
#train_X가 여러번 반복하면 누적 증가되어 이해가 필요 
print(train_X.shape)
# Out:
# (120000, 28, 28, 1)
# (150000, 28, 28, 1)

# %%
# 6.16 VGGNet style 네트워크 + Image Augmentation 학습
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same',
                           activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()
#분류 정확도가 92.88으로 92.52보다 약간 증가
model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 18s 10ms/step - loss: 0.5837 - accuracy: 0.7886 - val_loss: 0.3332 - val_accuracy: 0.8776
# Epoch 2/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.3685 - accuracy: 0.8682 - val_loss: 0.2845 - val_accuracy: 0.8969
# Epoch 3/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.3270 - accuracy: 0.8841 - val_loss: 0.2539 - val_accuracy: 0.9046
# Epoch 4/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.3009 - accuracy: 0.8907 - val_loss: 0.2401 - val_accuracy: 0.9099
# Epoch 5/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2879 - accuracy: 0.8976 - val_loss: 0.2355 - val_accuracy: 0.9133
# Epoch 6/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2780 - accuracy: 0.8992 - val_loss: 0.2329 - val_accuracy: 0.9091
# Epoch 7/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2740 - accuracy: 0.9024 - val_loss: 0.2237 - val_accuracy: 0.9187
# Epoch 8/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2574 - accuracy: 0.9068 - val_loss: 0.2195 - val_accuracy: 0.9206
# Epoch 9/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2557 - accuracy: 0.9095 - val_loss: 0.2215 - val_accuracy: 0.9209
# Epoch 10/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2527 - accuracy: 0.9088 - val_loss: 0.2057 - val_accuracy: 0.9245
# Epoch 11/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2495 - accuracy: 0.9117 - val_loss: 0.2223 - val_accuracy: 0.9163
# Epoch 12/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2476 - accuracy: 0.9103 - val_loss: 0.2194 - val_accuracy: 0.9210
# Epoch 13/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2402 - accuracy: 0.9128 - val_loss: 0.2061 - val_accuracy: 0.9279
# Epoch 14/25
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.2408 - accuracy: 0.9149 - val_loss: 0.2074 - val_accuracy: 0.9283
# Epoch 15/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2358 - accuracy: 0.9150 - val_loss: 0.2060 - val_accuracy: 0.9267
# Epoch 16/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2352 - accuracy: 0.9168 - val_loss: 0.2049 - val_accuracy: 0.9247
# Epoch 17/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2346 - accuracy: 0.9151 - val_loss: 0.2088 - val_accuracy: 0.9239
# Epoch 18/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2371 - accuracy: 0.9160 - val_loss: 0.2376 - val_accuracy: 0.9139
# Epoch 19/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2335 - accuracy: 0.9160 - val_loss: 0.2061 - val_accuracy: 0.9290
# Epoch 20/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2325 - accuracy: 0.9177 - val_loss: 0.2040 - val_accuracy: 0.9275
# Epoch 21/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2272 - accuracy: 0.9184 - val_loss: 0.2150 - val_accuracy: 0.9216
# Epoch 22/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2296 - accuracy: 0.9183 - val_loss: 0.2030 - val_accuracy: 0.9295
# Epoch 23/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2323 - accuracy: 0.9166 - val_loss: 0.2108 - val_accuracy: 0.9257
# Epoch 24/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2233 - accuracy: 0.9205 - val_loss: 0.1928 - val_accuracy: 0.9304
# Epoch 25/25
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.2290 - accuracy: 0.9191 - val_loss: 0.1988 - val_accuracy: 0.9298
# [0.21379819512367249, 0.9230999946594238]
